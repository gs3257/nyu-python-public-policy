# %% [markdown]
# <a href="https://colab.research.google.com/github/gs3257/nyu-python-public-policy/blob/master/HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt 
import numpy as np
import statsmodels.api as sm

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data_revised.csv', header='infer')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,19,20,22,33,36,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sidewalk_cleanliness = pd.read_csv('https://data.cityofnewyork.us/api/views/rqhp-hivt/rows.csv?accessType=DOWNLOAD', header='infer')

# %%
sidewalk_cleanliness.head(50)
# Out:
#         Month        Borough  Community Board District Cleaning Section  \
# 0   2018 / 10       Brooklyn               15    BKS15           BKS154
# 1   2018 / 10  Staten Island                1     SI01            SI013
# 2   2018 / 10  Staten Island                1     SI01            SI014
# 3   2018 / 10       Brooklyn               16    BKN16          BKN1612
# 4   2018 / 10  Staten Island                2     SI02            SI021
# 5   2018 / 10  Staten Island                2     SI02            SI022
# 6   2018 / 10  Staten Island                2     SI02            SI023
# 7   2018 / 10  Staten Island                2     SI02            SI024
# 8   2018 / 10  Staten Island                3     SI03            SI031
# 9   2018 / 10  Staten Island                3     SI03            SI032
# 10  2018 / 10  Staten Island                3     SI03            SI033
# 11  2018 / 10  Staten Island                3     SI03            SI034
# ...

# %%
set(sidewalk_cleanliness['Acceptable Sidewalks %'])
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  92.63,
#  nan,
#  nan,
#  nan,
#  92.13,
#  92.38,
#  94.15,
#  95.59,
#  95.34,
#  94.36,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  93.88,
#  nan,
#  nan,
#  nan,
#  40.0,
#  83.75,
#  83.5,
#  83.0,
#  50.0,
#  82.52,
#  52.0,
#  96.59,
#  54.17,
#  95.86,
#  55.0,
#  57.89,
#  58.33,
#  53.06,
#  60.0,
#  60.78,
#  62.5,
#  63.16,
#  64.0,
#  65.0,
#  66.67,
#  67.5,
#  68.75,
#  68.0,
#  70.0,
#  70.83,
#  72.5,
#  73.91,
#  72.73,
#  75.0,
#  76.92,
#  73.2,
#  78.26,
#  79.49,
#  78.95,
#  81.63,
#  82.0,
#  81.58,
#  84.75,
#  85.23,
#  86.21,
#  86.49,
#  88.43,
#  89.16,
#  89.41,
#  91.89,
#  92.62,
#  92.37,
#  94.64,
#  95.35,
#  96.08,
#  97.56,
#  98.8,
#  96.83,
#  95.1,
#  93.62,
#  98.81,
#  97.83,
#  96.34,
#  96.1,
#  97.06,
#  98.36,
#  100.0,
#  98.59,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  86.25,
#  96.63,
#  86.75,
# ...
